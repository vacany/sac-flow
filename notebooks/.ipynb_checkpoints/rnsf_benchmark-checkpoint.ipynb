# %% [markdown]
# # Benchmarking on LiDAR dataset
#     - Argoverse, Nuscenes, Waymo multi-frame

# %%
# Imports
import os

os.chdir('/home/vacekpa2/4D-RNSFP')
import torch
import numpy as np
import pandas as pd
from tqdm import tqdm
from data.dataloader import SFDataset4D, NSF_dataset
from models.RSNF import RigidNeuralPrior, NeuralPrior
from loss.flow import *
from ops.metric import SceneFlowMetric
from vis.deprecated_vis import imshow, visualize_flow3d

from time import time

# %%
### Main training loop
# to config?

# This reloads module for development. Nice!
# It reloads all modules after
# %load_ext autoreload
# %autoreload 2

from benchmark.exp_config import toy_exp_list
import builtins
from IPython.lib import deepreload
builtins.reload = deepreload.reload
from models.RSNF import * #RigidNeuralPrior, NeuralPrior, FreespaceRigidNeuralPrior


# todo setup everything with ground truth info to know if that helps []
# todo sceneflow metric for multiple runs []
device = torch.device('cuda:0')
# 
# def run_sceneflow_experiment(exp_config):
#     
#     for run in range(exp_config['nbr_of_runs']):
#         SF_metric = SceneFlowMetric()  
#         dataset = SFDataset4D(**exp_config)
#         
#         # builder?
#         # model = NeuralPrior(lr=0.008, early_stop=5, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8).to(device)
#         model = RigidNeuralPrior(lr=0.008, early_stop=5, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8).to(device)
#         # model = FreespaceRigidNeuralPrior(lr=0.008, early_stop=10, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8).to(device)
#         
#         print("Processing: ", exp_config['dataset_type'].capitalize())
#         print('With Model: ', model._get_name())
#         
#         for frame_id in tqdm(range(len(dataset))):
#             
#             data = dataset.__getitem__(frame_id)   
#             
#             data['pc1'] = data['pc1'].to(device)
#             data['pc2'] = data['pc2'].to(device)
#             data['gt_flow'] = data['gt_flow'].to(device)
#             
#             model.initialize()    
#                 
#             start_time = time()
#             output = model(data)
#             end_time = time()
#             data['eval_time'] = end_time - start_time
#             
#             pred_flow = output['pred_flow']
#             
#         
#             SF_metric.update(data)    
#             
#             if frame_id == 0:break
#             
#         print(SF_metric.get_metric().mean())

metric_df = {'RigidNeuralPrior' : [],
             'NeuralPrior' : []}

for run in range(2):
    
    for model_name in ['RigidNeuralPrior', 'NeuralPrior']:#, 'RigidNeuralPrior']:
    
    
        model = getattr(sys.modules[__name__], model_name)(lr=0.008, early_stop=100, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8).to(device)
        # model = NeuralPrior(lr=0.008, early_stop=5, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8).to(device)
        # model = RigidNeuralPrior(lr=0.008, early_stop=5, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8).to(device)
        # model = BatchRigidNeuralPrior(lr=0.008, early_stop=5, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8, verbose=True).to(device)
        # model = FreespaceRigidNeuralPrior(lr=0.008, early_stop=10, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8).to(device)
        
        for exp_config in toy_exp_list[-1:]:
            
            SF_metric = SceneFlowMetric()  
            
            # dataset = SFDataset4D(**exp_config)
            dataset = NSF_dataset(root_dir='/mnt/personal/vacekpa2/sceneflow/', dataset_type='waymo')
            
            # model = NeuralPrior(lr=0.008, early_stop=5, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8).to(device)
            # model = RigidNeuralPrior(lr=0.008, early_stop=5, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8).to(device)
            # model = BatchRigidNeuralPrior(lr=0.008, early_stop=5, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8, verbose=True).to(device)
            # model = FreespaceRigidNeuralPrior(lr=0.008, early_stop=10, loss_diff=0.001, dim_x=3, filter_size=128, layer_size=8).to(device)
            
            print("Processing: ", exp_config['dataset_type'].capitalize(), 'run: ', run)
            print('With Model: ', model._get_name())
            
            # for frame_id in tqdm(range(len(dataset))):
            for frame_id in tqdm(range(len(dataset))):
                
                # data = dataset.__getitem__(frame_id)   
                data = dataset.__next__()
                
                data['pc1'] = data['pc1'].to(device)
                data['pc2'] = data['pc2'].to(device)
                data['gt_flow'] = data['gt_flow'].to(device)
                # data['relative_pose']
                # data['pose1']
                # data['pose2']
                model.initialize()    
                    
                start_time = time()
                output = model(data)
                end_time = time()
                data['eval_time'] = end_time - start_time
                
                pred_flow = output['pred_flow']
                
                # After    
                # 
                SF_metric.update(data)
                
                
                # computed_pose = model.RigidTransform.construct_pose()  
                
                
                # if frame_id == 0: break    
            #
            metric_df[model_name].append(SF_metric.get_metric())
            print(SF_metric.get_metric().mean())
            # different testing samples in waymo
            # todo store csv results and plots
            # metric to class and to benchmark 
        # print(model.RigidTransform.translation)
    # visualize_flow3d(data['pc1'][0], data['pc2'][0], pred_flow[0])
    # run_sceneflow_experiment(exp_config)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#    version dataset_type data_split sequence  n_frames  only_first  run
# 0      1.0        waymo      train        *         1        True    0
# 1      1.0        waymo      train        *         1        True    1
# 2      1.0        waymo      train        *         1        True    2
# Processing:  Waymo
# With Model:  RigidNeuralPrior
#   0%|          | 1/202 [00:02<08:22,  2.50s/it]
# Processing:  Waymo
# With Model:  RigidNeuralPrior
#   0%|          | 1/202 [00:02<08:15,  2.47s/it]
# Processing:  Waymo
# With Model:  RigidNeuralPrior
#   0%|          | 1/202 [00:02<08:12,  2.45s/it]
# Processing:  Waymo
# With Model:  NeuralPrior
#   0%|          | 1/202 [00:02<07:16,  2.17s/it]
# Processing:  Waymo
# With Model:  NeuralPrior
#   0%|          | 1/202 [00:02<07:18,  2.18s/it]
# Processing:  Waymo
# With Model:  NeuralPrior
#   0%|          | 1/202 [00:02<07:17,  2.18s/it]

# %%
df = metric_df['RigidNeuralPrior'][0]
df[df['EPE'] < 10].mean()   # find that frame

##### Early Patience 70!
# Processing:  Waymo run:  0
# With Model:  RigidNeuralPrior
# 
# 100%|██████████| 202/202 [03:21<00:00,  1.00it/s]
# 
# EPE           0.064
# AS           85.744
# AR           92.937
# Angle         0.314
# Out           0.297
# Eval_Time     0.966
# dtype: float64
# Processing:  Waymo run:  1
# With Model:  RigidNeuralPrior
# 
# 100%|██████████| 202/202 [03:19<00:00,  1.01it/s]
# 
# EPE          116.737
# AS            85.738
# AR            93.022
# Angle          0.311
# Out            0.289
# Eval_Time      0.957
# dtype: float64
# Processing:  Waymo run:  2
# With Model:  RigidNeuralPrior
# 
# 100%|██████████| 202/202 [03:19<00:00,  1.01it/s]
# 
# EPE          263420.203
# AS               85.377
# AR               93.158
# Angle             0.313
# Out               0.289
# Eval_Time         0.954
# dtype: float64
# Processing:  Waymo run:  3
# With Model:  RigidNeuralPrior
# 
# 100%|██████████| 202/202 [03:19<00:00,  1.01it/s]
# 
# EPE          3.485e+06
# AS           8.501e+01
# AR           9.247e+01
# Angle        3.221e-01
# Out          2.879e-01
# Eval_Time    9.572e-01
# dtype: float64
# Processing:  Waymo run:  4
# With Model:  RigidNeuralPrior
# 
# 100%|██████████| 202/202 [03:22<00:00,  1.00s/it]
# 
# EPE           0.067
# AS           85.715
# AR           92.706
# Angle         0.311
# Out           0.294
# Eval_Time     0.973
# dtype: float64
# Processing:  Waymo run:  0
# With Model:  NeuralPrior
# 
# 100%|██████████| 202/202 [02:31<00:00,  1.33it/s]
# 
# EPE           0.073
# AS           82.960
# AR           91.448
# Angle         0.341
# Out           0.286
# Eval_Time     0.720
# dtype: float64
# Processing:  Waymo run:  1
# With Model:  NeuralPrior
# 
# 100%|██████████| 202/202 [02:31<00:00,  1.33it/s]
# 
# EPE           0.083
# AS           82.086
# AR           90.844
# Angle         0.346
# Out           0.293
# Eval_Time     0.720
# dtype: float64
# Processing:  Waymo run:  2
# With Model:  NeuralPrior
# 
# 100%|██████████| 202/202 [02:31<00:00,  1.33it/s]
# 
# EPE           0.078
# AS           82.806
# AR           90.980
# Angle         0.344
# Out           0.287
# Eval_Time     0.720
# dtype: float64
# Processing:  Waymo run:  3
# With Model:  NeuralPrior
# 
#

# %%
# show plots
# import matplotlib.pyplot as plt
# from vis.deprecated_vis import imshow
# 
# datasets = []
# epes = []
# variance = []
# 
# 
# 
# 
# 
# 
# for i in range(len(toy_exp_list)):
#     exp_config = toy_exp_list[i]
#     datasets.append(exp_config['dataset_type'])
#     metric_df = metric_list[i]
#     epes.append(metric_df['epe'].mean())
#     # for multiple exps, this is not for one exp run!
#     variance.append(metric_df['epe'].var())
#     
# 
# # plt.plot(datasets, epes, '*')
# # metric_df.describe()
# 
# # plt.errorbar(datasets, epes, yerr=variance, fmt='o')
# # imshow(plt)
# 
# datasets = [d.capitalize() for d in datasets]
# # RigidNeuralPrior:  ['argoverse', 'nuscenes', 'waymo'] [0.02453843277807419, 0.1638741924190054, 0.027922496817115207]
# # NeuralPrior: ['argoverse', 'nuscenes', 'waymo'] [0.025703593257528086, 0.22086603033776378, 0.02914426555060714]
# plt.close()
# plt.grid()
# plt.title('EPE comparison')
# plt.xlabel('Datasets')
# plt.ylabel('EPE')
# # todo bars better, take from experiments and set up benchamark utils
# baseArtist = plt.Line2D((0,1),(0,0), color='b', alpha=0.7, linewidth=10)
# oursArtist = plt.Line2D((0,1),(0,0), color='g', alpha=0.9, linewidth=10)
# plt.legend([baseArtist, oursArtist], ['NeuralPrior', 'Proposed'], loc='upper right', fontsize=15)
# plt.plot(datasets, [0.02453843277807419, 0.1638741924190054, 0.027922496817115207], 'g*', markersize=15, alpha=0.9, markeredgecolor='black')
# plt.plot(datasets, [0.025703593257528086, 0.22086603033776378, 0.02914426555060714], 'bs', markersize=15, alpha=0.7, markeredgecolor='black')
# imshow(fig=plt)
# Out:
# torch.Size([28012, 3])
# torch.Size([28012, 3])

# %% [markdown]
# # Contribution
# ##### 1) Introducing sequentialness of the data into SceneFlow
# ##### 2) Introducing concept of Freespace as loss to SceneFlow
# ##### 3) Introducing Global Map as correspondence improvement to SceneFlow
# ##### 4) Introducing Ego-Kinematic as loss to SceneFlow
# ##### Optional) Proposing Efficient computation of K-NN for real-time (Not sure, will see how it goes when implementing cyclic smoothness to 4D)
#
# &nbsp;
# &nbsp;
# # Main SOTA Baseline
# ##### FastNeuralPrior - realtime NeuralPrior

# %%
imshow(path='paper/diagrams/pipeline-current.png')

# %%
# Out:
#       EPE       AS       AR      Angle    Out  Eval_Time
# 0   0.251   50.438   66.045  3.586e-01  0.110      0.647
# 1   0.012   97.739   98.678  1.000e+00  1.254      1.583
# 2   0.030   94.416   96.365  4.376e-02  0.019      1.984
# 3   0.042   88.898   95.869  1.325e-01  0.077      1.485
# 4   0.049   96.655   97.900  8.940e-02  0.068      1.157
# 6   0.054   77.601   95.783  7.019e-01  0.169      1.382
# 7   0.024   90.967   97.801  6.902e-02  0.028      1.404
# 8   0.015  100.000  100.000  0.000e+00  0.010      1.435
# 9   0.127   95.129   95.271  4.729e-02  0.010      1.251
# 10  0.021   95.046   96.410  9.936e-01  0.183      1.533
# 11  0.020   93.620   99.567  1.188e-01  0.042      1.566
# 12  0.110   80.911   93.961  6.039e-02  0.026      1.167
# 13  0.023   95.202   98.861  2.968e-01  0.083      1.329
# 14  0.051   87.627   88.455  9.781e-01  0.978      0.990
# 15  0.025   97.120   99.306  7.421e-03  0.015      1.755
# ...
